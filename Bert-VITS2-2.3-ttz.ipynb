# %% [markdown]
# #获取库并安装依赖

# %%
# !git clone https://github.com/fishaudio/Bert-VITS2

# %%
# %cd /content/Bert-VITS2
# !pip install -r requirements.txt

# %% [markdown]
# #下载必要的模型文件

# %%
# %cd /content/Bert-VITS2/emotional/wav2vec2-large-robust-12-ft-emotion-msp-dim
# !wget https://huggingface.co/audeering/wav2vec2-large-robust-12-ft-emotion-msp-dim/resolve/main/pytorch_model.bin
# %cd /content/Bert-VITS2/bert/chinese-roberta-wwm-ext-large
# !wget https://huggingface.co/hfl/chinese-roberta-wwm-ext-large/resolve/main/pytorch_model.bin?
# %cd /content/Bert-VITS2/bert/deberta-v2-large-japanese-char-wwm
# !wget https://huggingface.co/ku-nlp/deberta-v2-large-japanese-char-wwm/resolve/main/pytorch_model.bin
# %cd /content/Bert-VITS2/bert/deberta-v3-large
# !wget https://huggingface.co/microsoft/deberta-v3-large/resolve/main/pytorch_model.bin
# %cd /content/Bert-VITS2/slm/wavlm-base-plus
# !wget https://huggingface.co/microsoft/wavlm-base-plus/resolve/main/pytorch_model.bin

# %% [markdown]
# #下载妥妥子模型

# %%
# %cd /content/Bert-VITS2
# !mkdir -p Data/ttz
# %cd /content/Bert-VITS2/Data/ttz
# !wget https://github.com/baka-9/My-Some-Files/releases/download/Bert-VITS2-Mods-ttz-2.3/config.json
# !wget https://github.com/baka-9/My-Some-Files/releases/download/Bert-VITS2-Mods-ttz-2.3/G_6000.pth
# !wget https://github.com/baka-9/My-Some-Files/releases/download/Bert-VITS2-Mods/G_8000.pth
# !wget https://github.com/baka-9/My-Some-Files/releases/download/Bert-VITS2-Mods/G_9000.pth

# %% [markdown]
# #配置文件

# %%
# %cd /content/Bert-VITS2
# !wget https://raw.githubusercontent.com/baka-9/My-Some-Files/Bert-VITS2-ttz-colab/config-ttz-colab-1.yml
# !mv config-ttz-colab-1.yml config.yml

# %% [markdown]
# #启动！

# %%
# !ssh-keygen -q -t rsa -N '' -f ~/.ssh/id_rsa <<<y
# !ssh-keyscan -t rsa remote.moe >> ~/.ssh/known_hosts

# %%
# %cd /content/Bert-VITS2
# !python webui.py
